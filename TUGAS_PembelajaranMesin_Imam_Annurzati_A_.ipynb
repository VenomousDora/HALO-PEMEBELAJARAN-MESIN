# %% [markdown]
# <a href="https://colab.research.google.com/github/VenomousDora/HALO-PEMEBELAJARAN-MESIN/blob/main/TUGAS_PembelajaranMesin_Imam_Annurzati_A_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset = '/content/nba2k-full.csv'
data = pd.read_csv(dataset)
data
# Out:
#                  full_name  rating jersey                   team position  \
# 0             LeBron James      97    #23     Los Angeles Lakers        F
# 1            Kawhi Leonard      97     #2   Los Angeles Clippers        F
# 2    Giannis Antetokounmpo      96    #34        Milwaukee Bucks      F-G
# 3             Kevin Durant      96     #7          Brooklyn Nets        F
# 4             James Harden      96    #13        Houston Rockets        G
# ..                     ...     ...    ...                    ...      ...
# 459             Chris Paul      88     #3  Oklahoma City Thunder        G
# 460           Bradley Beal      88     #3     Washington Wizards        G
# 461            Rudy Gobert      87    #27              Utah Jazz        C
# 462             Kyle Lowry      87     #7        Toronto Raptors        G
# 463     Kristaps Porzingis      87     #6       Dallas Mavericks      F-C
#
#         b_day       height                weight     salary country  \
# ...

# %%
data.head()
# Out:
#                full_name  rating jersey                  team position  \
# 0           LeBron James      97    #23    Los Angeles Lakers        F
# 1          Kawhi Leonard      97     #2  Los Angeles Clippers        F
# 2  Giannis Antetokounmpo      96    #34       Milwaukee Bucks      F-G
# 3           Kevin Durant      96     #7         Brooklyn Nets        F
# 4           James Harden      96    #13       Houston Rockets        G
#
#       b_day       height                weight     salary country  draft_year  \
# 0  12/30/84   6-9 / 2.06  250 lbs. / 113.4 kg.  $37436858     USA        2003
# 1  06/29/91   6-7 / 2.01  225 lbs. / 102.1 kg.  $32742000     USA        2011
# 2  12/06/94  6-11 / 2.11  242 lbs. / 109.8 kg.  $25842697  Greece        2013
# 3  09/29/88  6-10 / 2.08  230 lbs. / 104.3 kg.  $37199000     USA        2007
# 4  08/26/89   6-5 / 1.96   220 lbs. / 99.8 kg.  $38199000     USA        2009
#
#   draft_round draft_peak          college  version
# ...

# %%
print(data.dtypes)
# Out:
# full_name      object
# rating          int64
# jersey         object
# team           object
# position       object
# b_day          object
# height         object
# weight         object
# salary         object
# country        object
# draft_year      int64
# draft_round    object
# draft_peak     object
# college        object
# version        object
# dtype: object

# %%
datanoid = data.drop(data.columns[2],axis=1)
datanoid
# Out:
#                  full_name  rating                   team position     b_day  \
# 0             LeBron James      97     Los Angeles Lakers        F  12/30/84
# 1            Kawhi Leonard      97   Los Angeles Clippers        F  06/29/91
# 2    Giannis Antetokounmpo      96        Milwaukee Bucks      F-G  12/06/94
# 3             Kevin Durant      96          Brooklyn Nets        F  09/29/88
# 4             James Harden      96        Houston Rockets        G  08/26/89
# ..                     ...     ...                    ...      ...       ...
# 459             Chris Paul      88  Oklahoma City Thunder        G  05/06/85
# 460           Bradley Beal      88     Washington Wizards        G  06/28/93
# 461            Rudy Gobert      87              Utah Jazz        C  06/26/92
# 462             Kyle Lowry      87        Toronto Raptors        G  03/25/86
# 463     Kristaps Porzingis      87       Dallas Mavericks      F-C  08/02/95
#
# ...

# %%
datanoid = data.drop(data.columns[14],axis=1)
datanoid
# Out:
#                  full_name  rating jersey                   team position  \
# 0             LeBron James      97    #23     Los Angeles Lakers        F
# 1            Kawhi Leonard      97     #2   Los Angeles Clippers        F
# 2    Giannis Antetokounmpo      96    #34        Milwaukee Bucks      F-G
# 3             Kevin Durant      96     #7          Brooklyn Nets        F
# 4             James Harden      96    #13        Houston Rockets        G
# ..                     ...     ...    ...                    ...      ...
# 459             Chris Paul      88     #3  Oklahoma City Thunder        G
# 460           Bradley Beal      88     #3     Washington Wizards        G
# 461            Rudy Gobert      87    #27              Utah Jazz        C
# 462             Kyle Lowry      87     #7        Toronto Raptors        G
# 463     Kristaps Porzingis      87     #6       Dallas Mavericks      F-C
#
#         b_day       height                weight     salary country  \
# ...

# %%
datanoid = data.drop(data.columns[10],axis=1)
datanoid
# Out:
#                  full_name  rating jersey                   team position  \
# 0             LeBron James      97    #23     Los Angeles Lakers        F
# 1            Kawhi Leonard      97     #2   Los Angeles Clippers        F
# 2    Giannis Antetokounmpo      96    #34        Milwaukee Bucks      F-G
# 3             Kevin Durant      96     #7          Brooklyn Nets        F
# 4             James Harden      96    #13        Houston Rockets        G
# ..                     ...     ...    ...                    ...      ...
# 459             Chris Paul      88     #3  Oklahoma City Thunder        G
# 460           Bradley Beal      88     #3     Washington Wizards        G
# 461            Rudy Gobert      87    #27              Utah Jazz        C
# 462             Kyle Lowry      87     #7        Toronto Raptors        G
# 463     Kristaps Porzingis      87     #6       Dallas Mavericks      F-C
#
#         b_day       height                weight     salary country  \
# ...

# %%
data.describe()
# Out:
#            rating   draft_year
# count  464.000000   464.000000
# mean    77.568966  2013.892241
# std      6.933780     3.997465
# min     67.000000  2001.000000
# 25%     73.000000  2011.000000
# 50%     76.000000  2015.000000
# 75%     80.000000  2017.000000
# max     97.000000  2019.000000

# %%
data.loc[:,"rating":].corr()
# Out:
# <ipython-input-22-c4308d371a1a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"rating":].corr()
#               rating  draft_year
# rating      1.000000   -0.406722
# draft_year -0.406722    1.000000

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='rating', y='draft_year', s=75, alpha=.5)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-15fbe6f3-400b-4f12-a6d8-7a6a1888387d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15fbe6f3-400b-4f12-a6d8-7a6a1888387d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "NBA 2k20 player dataset"
# Out:
# ...
# ref                               title                    size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------  -----------------------  ----  -------------------  -------------  ---------  ---------------
# isaienkov/nba2k20-player-dataset  NBA 2k20 player dataset  16KB  2022-12-25 12:45:59           4912         97  1.0

# %%
# !kaggle datasets download isaienkov/nba2k20-player-dataset
# Out:
# nba2k20-player-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/nba2k20-player-dataset.zip
# Out:
# Archive:  /content/nba2k20-player-dataset.zip
# replace nba2k-full.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: nba2k-full.csv

# %%
pd.read_csv('/content/nba2k20-player-dataset.zip')
# Out:
#                  full_name  rating jersey                   team position  \
# 0             LeBron James      97    #23     Los Angeles Lakers        F
# 1            Kawhi Leonard      97     #2   Los Angeles Clippers        F
# 2    Giannis Antetokounmpo      96    #34        Milwaukee Bucks      F-G
# 3             Kevin Durant      96     #7          Brooklyn Nets        F
# 4             James Harden      96    #13        Houston Rockets        G
# ..                     ...     ...    ...                    ...      ...
# 459             Chris Paul      88     #3  Oklahoma City Thunder        G
# 460           Bradley Beal      88     #3     Washington Wizards        G
# 461            Rudy Gobert      87    #27              Utah Jazz        C
# 462             Kyle Lowry      87     #7        Toronto Raptors        G
# 463     Kristaps Porzingis      87     #6       Dallas Mavericks      F-C
#
#         b_day       height                weight     salary country  \
# ...
